# %% [markdown]
# # Final Project (Josh Cacayan)
#
# **This project gets video game data from two datasets, which involve the ps4 games, xbox games, and other games out there.
# The purpose of this project is to measure qualitative and quantitative data from the three data sets, with a bunch of goals when analyzing the three. The following data measured in the experiment involve:
#
# **Top 10 games from the ps4, xbox one, and other game consoles
#
# **Merging ps4 games and x box one games and getting the most popular games from the two datasets
#
# **What Genre do most people play?
#
# **is there a difference between genre and the type of gaming system one plays?
#
# **Displaying countries in regards to what games they play (bar chart)
#
# **Is the xbox one or the ps4 more popular?

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# reads 3 datasets for video game sales and their data in regards to: xbox, playstation, and other consoles (nintendo) 
playstationFour = pd.read_csv("foo.csv", encoding='latin1')
xboxOne = pd.read_csv("XboxOne_GameSales.csv" , encoding = 'latin1')
otherVideoGames = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv", encoding = 'latin1')
videoGames = otherVideoGames.drop(['Critic_Score', 'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'], axis = 1)
#top 10 games of ___________ - numbers below the country columns indicate the sale percentage

# %%
#top 10 games of the playstation 4
playstationFour["Gaming Platform"] = "PS4"
playstationFour[0:10]
# Out:
#                              Game  Year             Genre  \
# 0              Grand Theft Auto V  2014            Action
# 1       Call of Duty: Black Ops 3  2015           Shooter
# 2           Red Dead Redemption 2  2018  Action-Adventure
# 3              Call of Duty: WWII  2017           Shooter
# 4                         FIFA 18  2017            Sports
# 5                         FIFA 17  2016            Sports
# 6                 Uncharted (PS4)  2016            Action
# 7                Spider-Man (PS4)  2018  Action-Adventure
# 8  Call of Duty: Infinite Warfare  2016           Shooter
# 9                       Fallout 4  2015      Role-Playing
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# 3                      Activision           4.67    6.21   0.40
# 4                       EA Sports           1.27    8.64   0.15
# 5                 Electronic Arts           1.26    7.95   0.12
# 6  Sony Interactive Entertainment           4.49    3.93   0.21
# 7  Sony Interactive Entertainment           3.64    3.39   0.32
# 8                      Activision           3.11    3.83   0.19
# 9              Bethesda Softworks           2.91    3.97   0.27
#
#    Rest of World  Global Gaming Platform
# 0           3.02   19.39             PS4
# 1           2.44   15.09             PS4
# 2           2.26   13.94             PS4
# 3           2.12   13.40             PS4
# 4           1.73   11.80             PS4
# 5           1.61   10.94             PS4
# 6           1.70   10.33             PS4
# 7           1.41    8.76             PS4
# 8           1.36    8.48             PS4
# 9           1.34    8.48             PS4

# %% [markdown]
# **In this table, it shows the top 10 games of the PS4, and all the continent sales in regards to each game. It also shows the publisher, genre, and what year it was made.

# %%
globalGameSalesPs4 = playstationFour.groupby("Genre")["Global"].sum()
ps4AndGenre = pd.DataFrame( {"Global" : globalGameSalesPs4}, columns = ['Global'] ).sort_values(by = 'Global', ascending = False)
ps4AndGenre.reset_index( level = 0 , inplace = True)
print(ps4AndGenre)
plt.title("Ps4 Popular Game Genres")
plt.xlabel("Genre")
plt.ylabel("Global Game Sales (Millions)")
ax = plt.subplot()
plt.xticks(rotation = 90)
ax.bar(ps4AndGenre['Genre'], ps4AndGenre['Global'])
# Out:
#                Genre  Global
# 0            Shooter  133.40
# 1             Action  132.91
# 2             Sports   92.19
# 3   Action-Adventure   61.56
# 4       Role-Playing   60.98
# 5             Racing   24.39
# 6           Fighting   19.00
# 7           Platform   17.44
# 8          Adventure   13.72
# 9               Misc   11.68
# 10             Music    4.71
# 11        Simulation    4.03
# 12               MMO    3.42
# 13             Party    0.61
# 14          Strategy    0.42
# 15      Visual Novel    0.28
# 16            Puzzle    0.23
# <BarContainer object of 17 artists>

# %% [markdown]
# **most of the games that are sold in the ps4 according to the dataset are action, sports, and shooter games

# %%
#top 10 games of the xbox one
xboxOneUpdated = xboxOne.drop(["Pos"], axis = 1)
xboxOneUpdated["Gaming Platform"] = "Xbox-One"
xboxOneUpdated[0:10]
# Out:
#                              Game    Year             Genre  \
# 0              Grand Theft Auto V  2014.0            Action
# 1       Call of Duty: Black Ops 3  2015.0           Shooter
# 2              Call of Duty: WWII  2017.0           Shooter
# 3           Red Dead Redemption 2  2018.0  Action-Adventure
# 4                       MineCraft  2014.0              Misc
# 5  Call of Duty: Advanced Warfare  2014.0           Shooter
# 6                   Battlefield 1  2016.0           Shooter
# 7                       Fallout 4  2015.0      Role-Playing
# 8               Halo 5: Guardians  2015.0           Shooter
# 9  Call of Duty: Infinite Warfare  2016.0           Shooter
#
#             Publisher  North America  Europe  Japan  Rest of World  Global  \
# 0      Rockstar Games           4.70    3.25   0.01           0.76    8.72
# 1          Activision           4.63    2.04   0.02           0.68    7.37
# 2          Activision           3.75    1.91   0.00           0.57    6.23
# 3      Rockstar Games           3.76    1.47   0.00           0.54    5.77
# 4   Microsoft Studios           3.23    1.71   0.00           0.49    5.43
# 5          Activision           3.25    1.49   0.01           0.48    5.22
# 6     Electronic Arts           3.37    1.26   0.02           0.48    5.13
# 7  Bethesda Softworks           2.94    1.62   0.02           0.45    5.03
# 8   Microsoft Studios           2.94    1.49   0.03           0.45    4.92
# 9          Activision           2.91    1.44   0.00           0.44    4.79
#
#   Gaming Platform
# 0        Xbox-One
# 1        Xbox-One
# 2        Xbox-One
# 3        Xbox-One
# 4        Xbox-One
# 5        Xbox-One
# 6        Xbox-One
# 7        Xbox-One
# 8        Xbox-One
# 9        Xbox-One

# %% [markdown]
# **In this table, it shows the top 10 games of the xbox-one, and all the continent sales in regards to each game. It also shows the publisher, genre, and what year it was made

# %%
globalGameSalesXbox = xboxOneUpdated.groupby("Genre")["Global"].sum()
xboxOneandGenre = pd.DataFrame( {"Global" : globalGameSalesXbox}, columns = ['Global'] ).sort_values(by = 'Global', ascending = False)
xboxOneandGenre.reset_index( level = 0 , inplace = True)
print(ps4AndGenre)
plt.title("Xbox-One Popular Game Genres")
plt.xlabel("Genre")
plt.ylabel("Global Game Sales (Millions)")
ax = plt.subplot()
plt.xticks(rotation = 90)
ax.bar(xboxOneandGenre['Genre'], xboxOneandGenre['Global'])
# Out:
#                Genre  Global
# 0            Shooter  133.40
# 1             Action  132.91
# 2             Sports   92.19
# 3   Action-Adventure   61.56
# 4       Role-Playing   60.98
# 5             Racing   24.39
# 6           Fighting   19.00
# 7           Platform   17.44
# 8          Adventure   13.72
# 9               Misc   11.68
# 10             Music    4.71
# 11        Simulation    4.03
# 12               MMO    3.42
# 13             Party    0.61
# 14          Strategy    0.42
# 15      Visual Novel    0.28
# 16            Puzzle    0.23
# <BarContainer object of 16 artists>

# %% [markdown]
# **In this dataset, the most popular game genres for the x box include shooter, action, & sports.

# %% [markdown]
# **Both of these datasets have similar trends, with shooting, action, and sports being the most popular games. There are more global game sales in the ps4 due to the fact that there are more people who play the ps4 compared to the xbox-one. More people play shooter games compared to the other games in the xbox while  the ps4 is more widespread.

# %%
allVideoGamesOne = playstationFour.merge(xboxOneUpdated, how = 'outer').sort_values(by="Global", ascending = False)
allVideoGamesOne[0:10]
# Out:
#                           Game    Year             Genre  \
# 0           Grand Theft Auto V  2014.0            Action
# 1    Call of Duty: Black Ops 3  2015.0           Shooter
# 2        Red Dead Redemption 2  2018.0  Action-Adventure
# 3           Call of Duty: WWII  2017.0           Shooter
# 4                      FIFA 18  2017.0            Sports
# 5                      FIFA 17  2016.0            Sports
# 6              Uncharted (PS4)  2016.0            Action
# 7             Spider-Man (PS4)  2018.0  Action-Adventure
# 422         Grand Theft Auto V  2014.0            Action
# 9                    Fallout 4  2015.0      Role-Playing
#
#                           Publisher  North America  Europe  Japan  \
# 0                    Rockstar Games           6.06    9.71   0.60
# 1                        Activision           6.18    6.05   0.41
# 2                    Rockstar Games           5.26    6.21   0.21
# 3                        Activision           4.67    6.21   0.40
# 4                         EA Sports           1.27    8.64   0.15
# 5                   Electronic Arts           1.26    7.95   0.12
# 6    Sony Interactive Entertainment           4.49    3.93   0.21
# 7    Sony Interactive Entertainment           3.64    3.39   0.32
# 422                  Rockstar Games           4.70    3.25   0.01
# 9                Bethesda Softworks           2.91    3.97   0.27
#
#      Rest of World  Global Gaming Platform
# 0             3.02   19.39             PS4
# 1             2.44   15.09             PS4
# 2             2.26   13.94             PS4
# 3             2.12   13.40             PS4
# 4             1.73   11.80             PS4
# 5             1.61   10.94             PS4
# 6             1.70   10.33             PS4
# 7             1.41    8.76             PS4
# 422           0.76    8.72        Xbox-One
# 9             1.34    8.48             PS4

# %% [markdown]
# **These are the top 10 games in regards to the x-box one and the ps4 combined. There are more Ps4 top 10s as there are more people playing the ps4. There are duplicate games within the data, due to the fact that the ps4 and xbox sell similar games, showing how popular the game in general is.

# %%
globalGameSales = allVideoGamesOne.groupby("Genre")["Global"].sum()
globalGameGenre = pd.DataFrame( {"Global" : globalGameSales}, columns = ['Global'] ).sort_values(by = 'Global', ascending = False)
globalGameGenre.reset_index( level = 0 , inplace = True)
print(globalGameGenre)
plt.title("Popular game genres (X box and Playstation)")
plt.xlabel("Genre")
plt.ylabel("Global Game Sales (Millions)")
ax = plt.subplot()
plt.xticks(rotation = 90)
ax.bar(globalGameGenre['Genre'], globalGameGenre['Global'])
# Out:
#                Genre  Global
# 0            Shooter  225.61
# 1             Action  183.42
# 2             Sports  134.62
# 3   Action-Adventure   79.03
# 4       Role-Playing   77.04
# 5             Racing   42.36
# 6           Fighting   25.30
# 7               Misc   20.57
# 8           Platform   20.01
# 9          Adventure   18.54
# 10             Music    9.31
# 11        Simulation    6.53
# 12               MMO    4.94
# 13          Strategy    1.35
# 14             Party    0.61
# 15            Puzzle    0.46
# 16      Visual Novel    0.30
# <BarContainer object of 17 artists>

# %% [markdown]
# **Combined together, the most popular genre that the x box and ps4 sell in common were shooter games, showing that most people who play on these consoles play these specific genres.

# %%
xBoxVsPs4 = allVideoGamesOne.groupby(['Gaming Platform']).sum().plot(kind = 'pie', y = 'Global')

# %% [markdown]
# **According to the bar chart, most people play the ps4 compared to the x box one

# %% [markdown]
# **now we can compare this with another dataset, having data that has not only the ps4 and xboxone products, but with all of the other gaming systems such as nintendo systems, the xbox360, and the ps3.

# %%
othervideogames = pd.read_csv("Video_Games_Sales_as_at_22_Dec_2016.csv")
othervideogames[0:10]
videoGameDataFrame = othervideogames.rename(columns={ "Name": "Game", "Year_of_Release": "Year", "NA_Sales": "North America", "EU_Sales": "Europe", "JP_Sales" : "Japan", "Other_Sales": "Rest of World", "Global_Sales": "Global" })  
videoGameDataFrame["Gaming Platform"] = videoGameDataFrame["Platform"]
newGameData = videoGameDataFrame.drop(["Platform","Critic_Score", "Critic_Count", "User_Score", "User_Count", "Developer", "Rating"], axis = 1)
newGameData[0:10]
#videoGameDataFrame= pd.DataFrame({"Game": "Name", "Year" : "Year_of_Release", "North America": "NA_Sales", "Europe": "EU_Sales", "Japan": "JP_Sales", "Rest of World": "Other_Sales", "Global": "Global_Sales" }, columns = ["Game", "Year", "North America", "Europe", "Japan", "Rest of World", "Other_Sales", "Global"], index = None)
# Out:
#                         Game  Year         Genre Publisher  North America  \
# 0                 Wii Sports  2006        Sports  Nintendo          41.36
# 1          Super Mario Bros.  1985      Platform  Nintendo          29.08
# 2             Mario Kart Wii  2008        Racing  Nintendo          15.68
# 3          Wii Sports Resort  2009        Sports  Nintendo          15.61
# 4   Pokemon Red/Pokemon Blue  1996  Role-Playing  Nintendo          11.27
# 5                     Tetris  1989        Puzzle  Nintendo          23.20
# 6      New Super Mario Bros.  2006      Platform  Nintendo          11.28
# 7                   Wii Play  2006          Misc  Nintendo          13.96
# 8  New Super Mario Bros. Wii  2009      Platform  Nintendo          14.44
# 9                  Duck Hunt  1984       Shooter  Nintendo          26.93
#
#    Europe  Japan  Rest of World  Global Gaming Platform
# 0   28.96   3.77           8.45   82.53             Wii
# 1    3.58   6.81           0.77   40.24             NES
# 2   12.76   3.79           3.29   35.52             Wii
# 3   10.93   3.28           2.95   32.77             Wii
# 4    8.89  10.22           1.00   31.37              GB
# 5    2.26   4.22           0.58   30.26              GB
# 6    9.14   6.50           2.88   29.80              DS
# 7    9.18   2.93           2.84   28.92             Wii
# 8    6.94   4.70           2.24   28.32             Wii
# 9    0.63   0.28           0.47   28.31             NES

# %%
allVideoGames=newGameData.merge(allVideoGamesOne ,  how = 'outer').sort_values(by="Global", ascending = False)
allVideoGames[0:20]
# Out:
#                                             Game    Year         Genre  \
# 0                                     Wii Sports  2006.0        Sports
# 1                              Super Mario Bros.  1985.0      Platform
# 2                                 Mario Kart Wii  2008.0        Racing
# 3                              Wii Sports Resort  2009.0        Sports
# 4                       Pokemon Red/Pokemon Blue  1996.0  Role-Playing
# 5                                         Tetris  1989.0        Puzzle
# 6                          New Super Mario Bros.  2006.0      Platform
# 7                                       Wii Play  2006.0          Misc
# 8                      New Super Mario Bros. Wii  2009.0      Platform
# 9                                      Duck Hunt  1984.0       Shooter
# 10                                    Nintendogs  2005.0    Simulation
# 11                                 Mario Kart DS  2005.0        Racing
# 12                   Pokemon Gold/Pokemon Silver  1999.0  Role-Playing
# 13                                       Wii Fit  2007.0        Sports
# 14                            Kinect Adventures!  2010.0          Misc
# 15                                  Wii Fit Plus  2009.0        Sports
# 16                            Grand Theft Auto V  2013.0        Action
# 17                 Grand Theft Auto: San Andreas  2004.0        Action
# 18                             Super Mario World  1990.0      Platform
# 19  Brain Age: Train Your Brain in Minutes a Day  2005.0          Misc
#
#                  Publisher  North America  Europe  Japan  Rest of World  \
# 0                 Nintendo          41.36   28.96   3.77           8.45
# 1                 Nintendo          29.08    3.58   6.81           0.77
# 2                 Nintendo          15.68   12.76   3.79           3.29
# 3                 Nintendo          15.61   10.93   3.28           2.95
# 4                 Nintendo          11.27    8.89  10.22           1.00
# 5                 Nintendo          23.20    2.26   4.22           0.58
# 6                 Nintendo          11.28    9.14   6.50           2.88
# 7                 Nintendo          13.96    9.18   2.93           2.84
# 8                 Nintendo          14.44    6.94   4.70           2.24
# 9                 Nintendo          26.93    0.63   0.28           0.47
# 10                Nintendo           9.05   10.95   1.93           2.74
# 11                Nintendo           9.71    7.47   4.13           1.90
# 12                Nintendo           9.00    6.18   7.20           0.71
# 13                Nintendo           8.92    8.03   3.60           2.15
# 14  Microsoft Game Studios          15.00    4.89   0.24           1.69
# 15                Nintendo           9.01    8.49   2.53           1.77
# 16    Take-Two Interactive           7.02    9.09   0.98           3.96
# 17    Take-Two Interactive           9.43    0.40   0.41          10.57
# 18                Nintendo          12.78    3.75   3.54           0.55
# 19                Nintendo           4.74    9.20   4.16           2.04
#
#     Global Gaming Platform
# 0    82.53             Wii
# 1    40.24             NES
# 2    35.52             Wii
# 3    32.77             Wii
# 4    31.37              GB
# 5    30.26              GB
# 6    29.80              DS
# 7    28.92             Wii
# 8    28.32             Wii
# 9    28.31             NES
# 10   24.67              DS
# 11   23.21              DS
# 12   23.10              GB
# 13   22.70             Wii
# 14   21.81            X360
# 15   21.79             Wii
# 16   21.04             PS3
# 17   20.81             PS2
# 18   20.61            SNES
# 19   20.15              DS

# %%
popularSystems = allVideoGames.groupby(['Gaming Platform']).sum()
plt.title("Popular game systems")
plt.xlabel("Gaming Systems")
plt.ylabel("Users who play these systems")
ax = plt.subplot()
plt.xticks(rotation = 90)
ax.bar(allVideoGames['Gaming Platform'], popularSystems)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29440\3485874246.py in <module>
#       5 ax = plt.subplot()
#       6 plt.xticks(rotation = 90)
# ----> 7 ax.bar(allVideoGames['Gaming Platform'], popularSystems)
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1410     def inner(ax, *args, data=None, **kwargs):
#    1411         if data is None:
# -> 1412             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1413
#    1414         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2340                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2341
# -> 2342         x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2343             # Make args iterable too.
#    2344             np.atleast_1d(x), height, width, y, linewidth, hatch)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %% [markdown]
# **Conclusions
#
# **According to the two datasets in regards to global game sales, the most popular genres that people play on the x box  and the playstation are shooters, action, and sports games. The data is similar in regards to the genre due to the fact that both of the systems share popular games, as there is most likely a x box copy of a game that was on the ps4. Both are also made on the same time, making the games similar to one another.
#
# **One suprising factor that was found out in the experiment was how big the gap was between the ps4 players and the x box - one players is on the merged datasets. This is most likely due to the fact that the ps4 has many advantages involving the cheaper price, how it looks, and that ps4 games have a higher resolution compared to the xbox one according to: https://www.ps4home.com/top-7-reasons-why-the-ps4-is-currently-more-popular-than-the-xbox-one/#:~:text=Top%207%20Reasons%20why%20the%20PS4%20is%20currently,...%207%207.%20The%20PS4%E2%80%99s%20UI%20%28user%20interface%29
#
# **
